# %% [markdown]
# ---
# title: Bivariate Statistics
# subtitle: Foundations of Statistical Analysis in Python
# abstract: This notebook explores bivariate relationships through linear correlations, highlighting their strengths and limitations. Practical examples and visualizations are provided to help users understand and apply these statistical concepts effectively.
# author:
#   - name: Karol Flisikowski
#     affiliations:
#       - Gdansk University of Technology
#       - Chongqing Technology and Business University
#     orcid: 0000-0002-4160-1297
#     email: karol@ctbu.edu.cn
# date: 2025-05-03
# ---

# %% [markdown]
# ## Goals of this lecture
#
# There are many ways to *describe* a distribution.
#
# Here we will discuss:
# - Measurement of the relationship between distributions using **linear, rank correlations**.
# - Measurement of the relationship between qualitative variables using **contingency**.

# %% [markdown]
# ## Importing relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns ### importing seaborn
import pandas as pd
import scipy.stats as ss

# %%
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
df_pokemon = pd.read_csv("pokemon.csv")

# %% [markdown]
# ## Describing *bivariate* data with correlations
#
# - So far, we've been focusing on *univariate data*: a single distribution.
# - What if we want to describe how *two distributions* relate to each other?
#    - For today, we'll focus on *continuous distributions*.

# %% [markdown]
# ### Bivariate relationships: `height`
#
# - A classic example of **continuous bivariate data** is the `height` of a `parent` and `child`.
# - [These data were famously collected by Karl Pearson](https://www.kaggle.com/datasets/abhilash04/fathersandsonheight).

# %%
df_height = pd.read_csv("height.csv")
df_height.head(2)
# Out:
#    Father   Son
# 0    65.0  59.8
# 1    63.3  63.2

# %% [markdown]
# #### Plotting Pearson's height data

# %%
sns.scatterplot(data = df_height, x = "Father", y = "Son", alpha = .5);

# %% [markdown]
# ### Introducing linear correlations
#
# > A **correlation coefficient** is a number between $[–1, 1]$ that describes the relationship between a pair of variables.
#
# Specifically, **Pearson's correlation coefficient** (or Pearson's $r$) describes a (presumed) *linear* relationship.
#
# Two key properties:
#
# - **Sign**: whether a relationship is positive (+) or negative (–).
# - **Magnitude**: the strength of the linear relationship.

# %% [markdown]
# $$
# r = \frac{ \sum_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y}) }{ \sqrt{ \sum_{i=1}^{n} (x_i - \bar{x})^2 } \sqrt{ \sum_{i=1}^{n} (y_i - \bar{y})^2 } }
# $$
#
# Where:
# - $r$ - Pearson correlation coefficient
# - $x_i$, $y_i$ - values of the variables
# - $\bar{x}$, $\bar{y}$ - arithmetic means
# - $n$ - number of observations

# %% [markdown]
# Pearson's correlation coefficient measures the strength and direction of the linear relationship between two continuous variables. Its value ranges from -1 to 1:
# - 1 → perfect positive linear correlation
# - 0 → no linear correlation
# - -1 → perfect negative linear correlation
#
# This coefficient does not tell about nonlinear correlations and is sensitive to outliers.

# %% [markdown]
# ### Calculating Pearson's $r$ with `scipy`
#
# `scipy.stats` has a function called `pearsonr`, which will calculate this relationship for you.
#
# Returns two numbers:
#
# - $r$: the correlation coefficent.
# - $p$: the **p-value** of this correlation coefficient, i.e., whether it's *significantly different* from `0`.

# %%
ss.pearsonr(df_height['Father'], df_height['Son'])
# Out:
# PearsonRResult(statistic=np.float64(0.5011626808075912), pvalue=np.float64(1.272927574366214e-69))

# %% [markdown]
# #### Check-in
#
# Using `scipy.stats.pearsonr` (here, `ss.pearsonr`), calculate Pearson's $r$ for the relationship between the `Attack` and `Defense` of Pokemon.
#
# - Is this relationship positive or negative?
# - How strong is this relationship?

# %%
### Your code here
ss.pearsonr(df_pokemon['Attack'], df_pokemon['Defense'])

print("We get a resulting Pearson's coeficient of 0.439..")
print("This means, that there is a moderate positive linear correlation between the 'Attack' and 'Defense' attributes of Pokémon.")
print("In other words , Pokemon with higher attack value tend to also have higher defense value , but the relationship is not very strong : there is variability")
print(f"The p-value is p = 5.858479864289521e-39 , which extremely small, meaning the correlation is statistically significant.")
# Out:
# We get a resulting Pearson's coeficient of 0.439..
# This means, that there is a moderate positive linear correlation between the 'Attack' and 'Defense' attributes of Pokémon.
# In other words , Pokemon with higher attack value tend to also have higher defense value , but the relationship is not very strong : there is variability
# The p-value is p = 5.858479864289521e-39 , which extremely small, meaning the correlation is statistically significant.

# %% [markdown]
# #### Solution

# %%
ss.pearsonr(df_pokemon['Attack'], df_pokemon['Defense'])
# Out:
# PearsonRResult(statistic=np.float64(0.4386870551184896), pvalue=np.float64(5.858479864289521e-39))

# %% [markdown]
# #### Check-in
#
# Pearson'r $r$ measures the *linear correlation* between two variables. Can anyone think of potential limitations to this approach?

# %% [markdown]
# ### Limitations of Pearson's $r$
#
# - Pearson's $r$ *presumes* a linear relationship and tries to quantify its strength and direction.
# - But many relationships are **non-linear**!
# - Unless we visualize our data, relying only on Pearson'r $r$ could mislead us.

# %% [markdown]
# #### Non-linear data where $r = 0$

# %%
x = np.arange(1, 40)
y = np.sin(x)
p = sns.lineplot(x = x, y = y)

# %%
### r is close to 0, despite there being a clear relationship!
ss.pearsonr(x, y)
# Out:
# PearsonRResult(statistic=np.float64(-0.04067793461845843), pvalue=np.float64(0.8057827185936625))

# %% [markdown]
# #### When $r$ is invariant to the real relationship
#
# All these datasets have roughly the same **correlation coefficient**.

# %%
df_anscombe = sns.load_dataset("anscombe")
sns.relplot(data = df_anscombe, x = "x", y = "y", col = "dataset");

# %%
# Compute correlation matrix
corr = df_pokemon.corr(numeric_only=True)

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create a heatmap
sns.heatmap(corr, 
            annot=True,         # Show correlation coefficients
            fmt=".2f",          # Format for coefficients
            cmap="coolwarm",    # Color palette
            vmin=-1, vmax=1,    # Fixed scale
            square=True,        # Make cells square
            linewidths=0.5,     # Line width between cells
            cbar_kws={"shrink": .75})  # Colorbar shrink

# Title and layout
plt.title("Correlation Heatmap", fontsize=16)
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ## Rank Correlations
#
# Rank correlations are measures of the strength and direction of a monotonic (increasing or decreasing) relationship between two variables. Instead of numerical values, they use ranks, i.e., positions in an ordered set.
#
# They are less sensitive to outliers and do not require linearity (unlike Pearson's correlation).
#
# ### Types of Rank Correlations
#
# 1. $ρ$ (rho) **Spearman's**
# - Based on the ranks of the data.
# - Value: from –1 to 1.
# - Works well for monotonic but non-linear relationships.
#
# $$
# \rho = 1 - \frac{6 \sum d_i^2}{n(n^2 - 1)}
# $$
#
# Where:
# - $d_i$ – differences between the ranks of observations,
# - $n$ – number of observations.
#
# 2. $τ$ (tau) **Kendall's**
# - Measures the number of concordant vs. discordant pairs.
# - More conservative than Spearman's – often yields smaller values.
# - Also ranges from –1 to 1.
#
# $$
# \tau = \frac{(C - D)}{\frac{1}{2}n(n - 1)}
# $$
#
# Where:
# - $τ$ — Kendall's correlation coefficient,
# - $C$ — number of concordant pairs,
# - $D$ — number of discordant pairs,
# - $n$ — number of observations,
# - $\frac{1}{2}n(n - 1)$ — total number of possible pairs of observations.
#
# What are concordant and discordant pairs?
# - Concordant pair: if $x_i$ < $x_j$ and $y_i$ < $y_j$, or $x_i$ > $x_j$ and $y_i$ > $y_j$.
# - Discordant pair: if $x_i$ < $x_j$ and $y_i$ > $y_j$, or $x_i$ > $x_j$ and $y_i$ < $y_j$.

# %% [markdown]
# ### When to use rank correlations?
# - When the data are not normally distributed.
# - When you suspect a non-linear but monotonic relationship.
# - When you have rank correlations, such as grades, ranking, preference level.

# %% [markdown]
# | Correlation type | Description | When to use |
# |------------------|-----------------------------------------------------|----------------------------------------|
# | Spearman's (ρ) | Monotonic correlation, based on ranks | When data are nonlinear or have outliers |
# | Kendall's (τ) | Counts the proportion of congruent and incongruent pairs | When robustness to ties is important |

# %% [markdown]
# ### Interpretation of correlation values
#
# | Range of values | Correlation interpretation |
# |------------------|----------------------------------|
# | 0.8 - 1.0 | very strong positive |
# | 0.6 - 0.8 | strong positive |
# | 0.4 - 0.6 | moderate positive |
# | 0.2 - 0.4 | weak positive |
# | 0.0 - 0.2 | very weak or no correlation |
# | < 0 | similarly - negative correlation |

# %%
# Compute Kendall rank correlation
corr_kendall = df_pokemon.corr(method='kendall', numeric_only=True)

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create a heatmap
sns.heatmap(corr, 
            annot=True,         # Show correlation coefficients
            fmt=".2f",          # Format for coefficients
            cmap="coolwarm",    # Color palette
            vmin=-1, vmax=1,    # Fixed scale
            square=True,        # Make cells square
            linewidths=0.5,     # Line width between cells
            cbar_kws={"shrink": .75})  # Colorbar shrink

# Title and layout
plt.title("Correlation Heatmap", fontsize=16)
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### Comparison of Correlation Coefficients
#
# | Property                | Pearson (r)                   | Spearman (ρ)                        | Kendall (τ)                          |
# |-------------------------|-------------------------------|--------------------------------------|---------------------------------------|
# | What it measures?       | Linear relationship           | Monotonic relationship (based on ranks) | Monotonic relationship (based on pairs) |
# | Data type               | Quantitative, normal distribution | Ranks or ordinal/quantitative data  | Ranks or ordinal/quantitative data   |
# | Sensitivity to outliers | High                          | Lower                               | Low                                   |
# | Value range             | –1 to 1                       | –1 to 1                             | –1 to 1                               |
# | Requires linearity      | Yes                           | No                                  | No                                    |
# | Robustness to ties      | Low                           | Medium                              | High                                  |
# | Interpretation          | Strength and direction of linear relationship | Strength and direction of monotonic relationship | Proportion of concordant vs discordant pairs |
# | Significance test       | Yes (`scipy.stats.pearsonr`)  | Yes (`spearmanr`)                   | Yes (`kendalltau`)                   |

# %% [markdown]
# Brief summary:
# - Pearson - best when the data are normal and the relationship is linear.
# - Spearman - works better for non-linear monotonic relationships.
# - Kendall - more conservative, often used in social research, less sensitive to small changes in data.

# %% [markdown]
# ### Your Turn
#
# For the Pokemon dataset, find the pairs of variables that are most appropriate for using one of the quantitative correlation measures. Calculate them, then visualize them.

# %%
from scipy.stats import pearsonr, spearmanr, kendalltau
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pokemons = pd.read_csv('pokemon.csv')

## Your code here
pearson_corr = pokemons.corr(method='pearson', numeric_only=True)

# spearman_corr = pokemons.corr(method='spearman', numeric_only=True)

# kendall_corr = pokemons.corr(method='kendall', numeric_only=True)

x = pokemons['Attack']
y = pokemons['Total']

r, p = pearsonr(x, y)

plt.figure(figsize=(8, 6))
sns.regplot(x=x, y=y, scatter_kws={'alpha':0.6})

plt.title(f'Pearson Correlation between Attack and Total')
plt.xlabel('Attack')
plt.ylabel('Total')
plt.tight_layout()
plt.show()

x2 = pokemons['Attack']
y2 = pokemons['Defense']

r2, p2 = pearsonr(x2, y2)

plt.figure(figsize=(8, 6))
sns.regplot(x=x2, y=y2, scatter_kws={'alpha':0.6})

plt.title(f'Pearson Correlation between Attack and Defense')
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.tight_layout()
plt.show()

sns.heatmap(pearson_corr, 
            annot=True,
            fmt=".2f",
            cmap="coolwarm",
            vmin=-1, vmax=1,
            square=True,
            linewidths=0.5,
            cbar_kws={"shrink": .75})

plt.title("Correlation Heatmap - Pearson", fontsize=16)
plt.tight_layout()

plt.show()

# sns.heatmap(kendall_corr, 
#             annot=True,
#             fmt=".2f",
#             cmap="coolwarm",
#             vmin=-1, vmax=1,
#             square=True,
#             linewidths=0.5,
#             cbar_kws={"shrink": .75})


# plt.title("Correlation Heatmap - Kendall", fontsize=16)
# plt.tight_layout()

# plt.show()

# sns.heatmap(spearman_corr, 
#             annot=True,
#             fmt=".2f",
#             cmap="coolwarm",
#             vmin=-1, vmax=1,
#             square=True,
#             linewidths=0.5,
#             cbar_kws={"shrink": .75})

# plt.title("Correlation Heatmap - Spearman", fontsize=16)
# plt.tight_layout()

# plt.show()

# %% [markdown]
# ## Correlation of Qualitative Variables
#
# A categorical variable is one that takes descriptive values ​​that represent categories—e.g. Pokémon type (Fire, Water, Grass), gender, status (Legendary vs. Normal), etc.
#
# Such variables cannot be analyzed directly using correlation methods for numbers (Pearson, Spearman, Kendall). Other techniques are used instead.

# %% [markdown]
# ### Contingency Table
#
# A contingency table is a special cross-tabulation table that shows the frequency (i.e., the number of cases) for all possible combinations of two categorical variables.
#
# It is a fundamental tool for analyzing relationships between qualitative features.
#
# #### Chi-Square Test of Independence
#
# The Chi-Square test checks whether there is a statistically significant relationship between two categorical variables.
#
# Concept:
#
# We compare:
# - observed values (from the contingency table),
# - with expected values, assuming the variables are independent.
#
# $$
# \chi^2 = \sum \frac{(O_{ij} - E_{ij})^2}{E_{ij}}
# $$
#
# Where:
# - $O_{ij}$ – observed count in cell ($i$, $j$),
# - $E_{ij}$ – expected count in cell ($i$, $j$), assuming independence.

# %% [markdown]
# ### Example: Calculating Expected Values and Chi-Square Statistic in Python
#
# Here’s how you can calculate the **expected values** and **Chi-Square statistic (χ²)** step by step using Python.
#
# ---
#
# #### Step 1: Create the Observed Contingency Table
# We will use the Pokémon example:
#
# | Type 1 | Legendary = False | Legendary = True | Total |
# |--------|-------------------|------------------|-------|
# | Fire   | 18                | 5                | 23    |
# | Water  | 25                | 3                | 28    |
# | Grass  | 20                | 2                | 22    |
# | Total  | 63                | 10               | 73    |

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Observed values (contingency table)
observed = np.array([
    [18, 5],  # Fire
    [25, 3],  # Water
    [20, 2]   # Grass
])

# Convert to DataFrame for better visualization
observed_df = pd.DataFrame(
    observed,
    columns=["Legendary = False", "Legendary = True"],
    index=["Fire", "Water", "Grass"]
)
print("Observed Table:")
print(observed_df)
# Out:
# Observed Table:
#        Legendary = False  Legendary = True
# Fire                  18                 5
# Water                 25                 3
# Grass                 20                 2

# %% [markdown]
# Step 2: Calculate Expected Values
# The expected values are calculated using the formula:
#
# $$ E_{ij} = \frac{\text{Row Total} \times \text{Column Total}}{\text{Grand Total}} $$
#
# You can calculate this manually or use scipy.stats.chi2_contingency, which automatically computes the expected values.

# %%
# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(observed)

# Convert expected values to DataFrame for better visualization
expected_df = pd.DataFrame(
    expected,
    columns=["Legendary = False", "Legendary = True"],
    index=["Fire", "Water", "Grass"]
)
print("\nExpected Table:")
print(expected_df)
# Out:
# Expected Table:
#        Legendary = False  Legendary = True
# Fire           19.849315          3.150685
# Water          24.164384          3.835616
# Grass          18.986301          3.013699

# %% [markdown]
# Step 3: Calculate the Chi-Square Statistic
# The Chi-Square statistic is calculated using the formula:
#
# $$ \chi^2 = \sum \frac{(O_{ij} - E_{ij})^2}{E_{ij}} $$
#
# This is done automatically by scipy.stats.chi2_contingency, but you can also calculate it manually:

# %%
# Manual calculation of Chi-Square statistic
chi2_manual = np.sum((observed - expected) ** 2 / expected)
print(f"\nChi-Square Statistic (manual): {chi2_manual:.4f}")
# Out:
# Chi-Square Statistic (manual): 1.8638

# %% [markdown]
# Step 4: Interpret the Results
# The chi2_contingency function also returns:
#
# p-value: The probability of observing the data if the null hypothesis (independence) is true.
# Degrees of Freedom (dof): Calculated as (rows - 1) * (columns - 1).

# %%
print(f"\nChi-Square Statistic: {chi2:.4f}")
print(f"p-value: {p:.4f}")
print(f"Degrees of Freedom: {dof}")
# Out:
# Chi-Square Statistic: 1.8638
# p-value: 0.3938
# Degrees of Freedom: 2

# %% [markdown]
# **Interpretation of the Chi-Square Test Result:**
#
# | Value               | Meaning                                         |
# |---------------------|-------------------------------------------------|
# | High χ² value       | Large difference between observed and expected values |
# | Low p-value         | Strong basis to reject the null hypothesis of independence |
# | p < 0.05            | Statistically significant relationship between variables |

# %% [markdown]
# ### Qualitative Correlations
#
# #### Cramér's V
#
# **Cramér's V** is a measure of the strength of association between two categorical variables. It is based on the Chi-Square test but scaled to a range of 0–1, making it easier to interpret the strength of the relationship.
#
# $$
# V = \sqrt{ \frac{\chi^2}{n \cdot (k - 1)} }
# $$
#
# Where:
# - $\chi^2$ – Chi-Square test statistic,
# - $n$ – number of observations,
# - $k$ – the smaller number of categories (rows/columns) in the contingency table.
#
# ---
#
# #### Phi Coefficient ($φ$)
#
# Application:
# - Both variables must be dichotomous (e.g., Yes/No, 0/1), meaning the table must have the smallest size of **2×2**.
# - Ideal for analyzing relationships like gender vs purchase, type vs legendary.
#
# $$
# \phi = \sqrt{ \frac{\chi^2}{n} }
# $$
#
# Where:
# - $\chi^2$ – Chi-Square test statistic for a 2×2 table,
# - $n$ – number of observations.
#
# ---
#
# #### Tschuprow’s T
#
# **Tschuprow’s T** is a measure of association similar to **Cramér's V**, but it has a different scale. It is mainly used when the number of categories in the two variables differs. This is a more advanced measure applicable to a broader range of contingency tables.
#
# $$
# T = \sqrt{\frac{\chi^2}{n \cdot (k - 1)}}
# $$
#
# Where:
# - $\chi^2$ – Chi-Square test statistic,
# - $n$ – number of observations,
# - $k$ – the smaller number of categories (rows or columns) in the contingency table.
#
# Application: Tschuprow’s T is useful when dealing with contingency tables with varying numbers of categories in rows and columns.
#
# ---
#
# ### Summary - Qualitative Correlations
#
# | Measure            | What it measures                                       | Application                     | Value Range     | Strength Interpretation       |
# |--------------------|--------------------------------------------------------|---------------------------------|------------------|-------------------------------|
# | **Cramér's V**     | Strength of association between nominal variables      | Any categories                  | 0 – 1           | 0.1–weak, 0.3–moderate, >0.5–strong |
# | **Phi ($φ$)**      | Strength of association in a **2×2** table             | Two binary variables            | -1 – 1          | Similar to correlation        |
# | **Tschuprow’s T**  | Strength of association, alternative to Cramér's V     | Tables with similar category counts | 0 – 1      | Less commonly used            |
# | **Chi² ($χ²$)**    | Statistical test of independence                       | All categorical variables       | 0 – ∞           | Higher values indicate stronger differences |

# %% [markdown]
# ### Example
#
# Let's investigate whether the Pokémon's type (type_1) is affected by whether the Pokémon is legendary.
#
# We'll use the **scipy** library.
#
# This library already has built-in functions for calculating various qualitative correlation measures.

# %%
from scipy.stats.contingency import association

# Contingency table:
ct = pd.crosstab(df_pokemon["Type 1"], df_pokemon["Legendary"])

# Calculating Cramér's V measure
V = association(ct, method="cramer") # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.contingency.association.html#association

print(f"Cramer's V: {V}") # interpret!
# Out:
# Cramer's V: 0.3361928228447545
# The value we obtained shows a weak association between Type 1 and the legendary status. This indicates that although there is some relationship, Type 1 by itself does not strongly determine whether a Pokémon is legendary.
# It would be interesting to see what we would get with different types.

# %% [markdown]
# ### Your turn
#
# What visualization would be most appropriate for presenting a quantitative, ranked, and qualitative relationship?
#
# Try to think about which pairs of variables could have which type of analysis based on the Pokemon data.
#
# ---

# %%
## Your code and discussion here
from scipy.stats import spearmanr
from scipy.stats import chi2_contingency
import numpy as np

# quantitative & quantitative
# for those values the best representation would be a scatter plot with linear correlation shown
# by a line -> if it's almost horizontal it means that there is almost no correlation
# to implement this idea we calculate the Pearson's r for some two groups of values
# then we show both groups on a regplot (one values on the x-axis, second on the y-axis)
# on which we also show the scatter and additionally we have regresion line

# as we can see below Speed and Defense have almost no correlation between them
# the regression line is almost horizontal which means that pearson's r is almost 0
# we can see that Pearson's r is around 0.02 which proves our theory

x = pokemons['Speed']
y = pokemons['Defense']

r, p = pearsonr(x, y)

plt.figure()
sns.regplot(x=x, y=y, scatter_kws={'alpha':0.6})
print(f"Pearson's r: {r:.2f}")
plt.title(f'Pearson Correlation between Speed and Defense')
plt.xlabel('Speed')
plt.ylabel('Defense')
plt.tight_layout()
plt.show()

#ranked & ranked
# for those values the best representation would be also a scatter plot with a regression line
# but this time the plot should be created using Spearman's method 
# because we don't have to assume linearity of our data

#as we can see below Total and HP have strong correlation because the
# Spearman's rho is quite close to 1.0 and the regression line is quite sloping

x = pokemons['Total'].rank()
y = pokemons['HP'].rank()

rho, p = spearmanr(x, y)

plt.figure()
sns.regplot(x=x, y=y, scatter_kws={'alpha':0.6})
plt.title(f'Spearman Correlation (Total vs HP): ρ = {rho:.2f}')
plt.xlabel('Rank Total')
plt.ylabel('Rank HP')
plt.show()

#qualitative & qualitative
# for showing correlations between two qualitative data we can use heatmap
# we can calculate contingency table-heatmap and additionally calcutale Cramer's v
# from the expample below we can see that correlation between Type 2 and Legendary is quite small
# Cramer's v value is close to 0.3 -> it means that correlation is weak
# on the contingency cross-table with heatmap we can see that our value is correct there are few Legendary pokemons
# that are additionally Type 2

contingency = pd.crosstab(pokemons['Type 2'], pokemons['Legendary'])
chi2, _, _, expected = chi2_contingency(contingency)

n = contingency.sum().sum()
min_dim = min(contingency.shape) - 1
cramers_v = np.sqrt(chi2 / (n * min_dim))

print(f"Cramér’s V: {cramers_v:.2f}")
sns.heatmap(contingency, annot=True, fmt="d")
plt.title('Type 1 vs Legendary')
plt.show()


#qualitative & ranked
# to show relation between qualitative & ranked values we can use boxplot
# from a plot like this we can read whether the rank of a qualitative datum is somehow related
# for example below we have Total data turned to ranked data and we compare it with Legendary criterion
# we can see that the higher Total rank is the more possible is that the pokemon is Legendary

pokemons['Total_rank'] = pokemons['Total'].rank()

plt.figure(figsize=(8, 5))
sns.boxplot(x='Legendary', y='Total_rank', data=pokemons)

plt.title('Distribution of Ranked Total Stats by Legendary Status')
plt.xlabel('Legendary')
plt.ylabel('Total (Ranked)')
plt.show()


#quantitative & qualitative
# for this data we can use boxplot to interpret the possible correlation
# on the boxplot we can see the distribution on Attack values by Legendary
# we can drew conclusion that :
# - the tendency is such that the higher the Attack is it's more possible that pokemon is Legendary
# - we need to remember it's just a tendency, from the boxplot we can observe that there are several outliers
#   there is a lot of outliers especially when the Legendary status is False

plt.figure(figsize=(8, 6))
sns.boxplot(x='Legendary', y='Attack', data=pokemons)
plt.xticks(rotation=45)
plt.title('Attack Distribution by Legendary')
plt.show()

#quantitative & ranked
# to show the correlation between quantitative & ranked data, we can once again
# plot a regplot with scatterplot -> we can see the distribution of HP ranking data and Speed values
# while the scatter plot shows the distribution, the red line shown on the plot shows us the tendency
# the calculated Spearman correlation is around 0.27 which means that the correlation is there but
# it's quite small

pokemons['HP_rank'] = pokemons['HP'].rank()
correlation, p = spearmanr(pokemons['Speed'], pokemons['HP_rank'])
print(f"Spearman correlation: {correlation:.2f}")
plt.figure()
# sns.scatterplot(x='Speed', y='HP_rank', data=pokemons)
sns.regplot(x='Speed', y='HP_rank', data=pokemons, scatter_kws={'alpha':0.5}, line_kws={"color": "red"}, ci=None)
plt.title('Speed vs HP Rank')
plt.show()
# Out:
# Pearson's r: 0.02
# Cramér’s V: 0.24
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HP_rank'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 110
#     101 plt.show()
#     103 #quantitative & ranked
#     104 # to show the correlation between quantitative & ranked data, we can once again
#     105 # plot a regplot with scatterplot -> we can see the distribution of HP ranking data and Speed values
#     106 # while the scatter plot shows the distribution, the red line shown on the plot shows us the tendency
#     107 # the calculated Spearman correlation is around 0.27 which means that the correlation is there but
#     108 # it's quite small
# --> 110 correlation, p = spearmanr(pokemons['Speed'], pokemons['HP_rank'])
#     111 print(f"Spearman correlation: {correlation:.2f}")
#     112 pokemons['HP_rank'] = pokemons['HP'].rank()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'HP_rank'

# %% [markdown]
# ## Heatmaps for qualitative correlations

# %%
# git clone https://github.com/ayanatherate/dfcorrs.git
# cd dfcorrs 
# pip install -r requirements.txt

from dfcorrs.cramersvcorr import Cramers
cram=Cramers()
# cram.corr(df_pokemon)
cram.corr(df_pokemon, plot_htmp=True)

# %% [markdown]
# ## Your turn!
#
# Load the "sales" dataset and perform the bivariate analysis together with necessary plots. Remember about to run data preprocessing before the analysis.

# %%
df_sales = pd.read_excel("sales.xlsx")

import missingno as msno

df_missing = df_sales.isna().copy()
df_missing['Store_Type'] = df_sales['Store_Type']
df_long = df_missing.melt(id_vars='Store_Type', var_name='Column', value_name='Is_Missing')
missing_counts = df_long[df_long['Is_Missing']].groupby(['Column','Store_Type']).sum()
print(missing_counts)
plt.figure()
sns.barplot(data = missing_counts, x='Column', y='Is_Missing', hue='Store_Type')
msno.matrix(df_sales)

#we can see that the data is missing at random - the missingness is somewhat related to store type as store type 3 has the most missing data
#also on missingness matrix we can see that day_temp, no_of_customers and sales tend to be missing together - is there any relation between them?
#question is what does store type 3 mean? is the data missing for a reason? do shops of that type purposly dont present their data? 
#as we do not have that inforamtion i will just drop these rows as, because due to the missingness of majority of the quantitative data, they will not give any insights for further analysis
df_sales=df_sales.dropna(subset=['Day_Temp'])
# Out:
#                             Is_Missing
# Column          Store_Type
# Day_Temp        2                    1
#                 3                    2
# No_of_Customers 2                    1
#                 3                    2
# Product_Quality 1                    1
#                 3                    1
# Sales           2                    1
#                 3                    2

# %%
df_sales['avg_consumer_exp'] = df_sales['Sales']/df_sales['No_of_Customers']
pearsonCorr = df_sales.corr(method='pearson', numeric_only=True)
sns.heatmap(pearsonCorr)
# Out:
# <Axes: >

# %%
sns.regplot(df_sales, x='Sales', y='avg_consumer_exp')
#we can see that the average consumer expenditure increases with increase of sales lineary
# Out:
# <Axes: xlabel='Sales', ylabel='avg_consumer_exp'>

# %%
sns.regplot(df_sales, x='No_of_Customers', y='Day_Temp')
# from graph we can deduce that the number of customers is related to day temp in interval (20,33) and the relation is about linear -> 
# if the temperature increases, the number of customers will likely increase also
# Out:
# <Axes: xlabel='No_of_Customers', ylabel='Day_Temp'>

# %%
store_counts = df_sales.groupby(['City_Type','Store_Type']).size().reset_index(name = 'count')
sns.barplot(data=store_counts,x='Store_Type',y='count', hue='City_Type')
#from this, graph, we can see how each store type is distributed around the cities
#what we can deduce from this is that stores type 3 can not be found in city 1 and 2, stores type 1 can not be found in city 3 stores type 2 are in every city
#what does it say about the stores and the market of each store type?
# Out:
# <Axes: xlabel='Store_Type', ylabel='count'>

# %%
plt.figure()
df_sales.boxplot(column = 'Sales', by='Store_Type', grid=None)
#from box plot we can see that stores type 2 have higher median and higher min value of sales -> so generally have higher sales than store type 1
#also the data for store type 1 is significantly left skeweed, so most of the data is below smaller than the median value
# we can not really deduct much from store type 3 as we have only one data entry given
# Out:
# <Axes: title={'center': 'Sales'}, xlabel='Store_Type'>

# %% [markdown]
# # Summary
#
# There are many ways to *describe* our data:
#
# - Measure **central tendency**.
#
# - Measure its **variability**; **skewness** and **kurtosis**.
#
# - Measure what **correlations** our data have.
#
# All of these are **useful** and all of them are also **exploratory data analysis** (EDA).
